# %% [markdown]
# This is based on https://pytorch.org/tutorials/beginner/pytorch_with_examples.html

# %%
# We are going to code this all by hand so we will of course need trusty old numpy
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
# Create random input and output data
x = np.linspace(-math.pi, math.pi, 2000)
y = np.sin(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# ##############################
# ### Task: write a neuron which can learn to make a thrid order polynomial approximate a sine function over this interval through backpropogation
# #############################
#
# 1. I have started you off with the hyper parameters you will need (you can change these values if you want)
# 2. You probably need to define the polynomial and its coefficients which you "learn"
# 3. You will need some sort of loss function
# 4. Randomly initiate (or don't) the weights (in this case the coefficients)
# 5. Calculate the gradient and update the weights (hint: we literally just covered the maths to do this in the slides before exercise 1)
# *** Hints***
# <details> <summary>Show / Hide</summary>
# <p>
# Loss function (and gradients for each coefficient) should be a single value so you need to add up all the differences .sum() may be your friend and easier than loops
#
#
# You will need to loop over a number of epochs
#
# </p>
# </details>
# 6. Plot your results (if you aren't too familiar with matplotlib, plt.plot(x,y) called multiple times in a cell will all plot on the same graph)
# 7. What happens if you run it for more/fewer epochs?
# 8. What happens if you change the learning rate?

# %%
learning_rate = 1e-6
epochs = 3

# %%
#code here

# %% [markdown]
# *** Suggested answer***
# <details> <summary>Show / Hide</summary>
# <p>
#
# # Randomly initialize weights
# a = np.random.randn()
# b = np.random.randn()
# c = np.random.randn()
# d = np.random.randn()
#
#
# for t in range(epochs):
#
#     # Forward pass: compute predicted y
#
#     # y = a + b x + c x^2 + d x^3
#
#     y_pred = a + b * x + c * x ** 2 + d * x ** 3
#
#     # Compute and print loss
#
#     loss = np.square(y_pred - y).sum()
#     if t % 100 == 99:
#         print(t, loss)
#
#     # Backprop to compute gradients of a, b, c, d with respect to loss
#
#     grad_y_pred = 2*(y_pred - y)
#     grad_a = grad_y_pred.sum()
#     grad_b = (grad_y_pred * x).sum()
#     grad_c = (grad_y_pred * x ** 2).sum()
#     grad_d = (grad_y_pred * x ** 3).sum()
#
#     # Update weights
#
#     a -= learning_rate * grad_a
#     b -= learning_rate * grad_b
#     c -= learning_rate * grad_c
#     d -= learning_rate * grad_d
#
# print(f'Result: y = {a} + {b} x + {c} x^2 + {d} x^3')
# </p>
# </details>

# %% [markdown]
# <details> <summary>Show / Hide</summary>
# <p>
#
# y_pred = a + b * x + c * x ** 2 + d * x ** 3
#
# plt.plot(x,y,'b')
# plt.plot(x,y_pred,'g')
# plt.show()
#
# </p>
# </details>
