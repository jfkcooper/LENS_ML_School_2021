# %% [markdown]
# ## What can go wrong
#
# Reinforcement learning algorithms can break in surprising, counterintuitive ways. In [this post](https://openai.com/blog/faulty-reward-functions/) one failure mode is explored, which is where you misspecify your reward function.

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('tlOIHko8ySg', width=400, height=300)

# %% [markdown]
# Source: https://openai.com/blog/faulty-reward-functions/

# %% [markdown]
# Another example: robot hand should learn how to put a red lego stone on a blue one. It has been rewarded for the hight of the bottom side of the red lego stone when it does not touch it.
#
# ![robot hand](https://hsto.org/webt/td/sz/sn/tdszsnxsm0jzkh-1h6wxfwcr180.gif)
#
# Image from https://habr.com/ru/company/skillfactory/blog/534448/

# %% [markdown]
# Sometimes RL agent can even discover errors in the simulators. In this example simulated robot had to learn how to walk:
#
# ![robot walk](https://hsto.org/webt/xb/nh/ip/xbnhips_xut6i4jjmfn0-0twpki.gif)
# Image from https://habr.com/ru/company/skillfactory/blog/534448/

# %% [markdown]
# ## References
#
# [[1]](http://incompleteideas.net/book/the-book.html) Richard S. Sutton and Andrew G. Barto, *Reinforcement Learning: An Introduction*,  MIT Press, Cambridge, MA, 2018
#
# [[2]](https://www.guru99.com/reinforcement-learning-tutorial.html) Reinforcement Learning: What is, Algorithms, Applications, Example
#
# [[3]](https://gym.openai.com/docs/) Openai gym documentation
#
# [[4]](https://github.com/yandexdataschool/Practical_RL) An open course on reinforcement learning. Taught by HSE University and Yandex School of Data Analysis (YSDA).
#
# [[5]](https://www.coursera.org/learn/practical-rl) Coursera course on Practical RL
#
# [[6]](https://arxiv.org/abs/1312.5602) Volodymyr Mnih, Koray Kavukcuoglu, David Silver, Alex Graves, Ioannis Antonoglou, Daan Wierstra, Martin Riedmiller, *Playing Atari with Deep Reinforcement Learning*,  arXiv:1312.5602v1
#
# [[7]](https://www.davidsilver.uk/teaching/) David Silver, *Lectures on Reinforcement Learning*, 2015
